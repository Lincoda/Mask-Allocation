# %%
from model import *
import numpy as np
import pandas as pd

# %%
vo =0.5
vn=0.7
𝜌 = 1
σo=0.5
σn=0.7
𝛿o=0.5
𝛿n=0.7
I=0.01
𝛼=0.0138
m_vals=np.linspace(0.15,0.75,3)

param=map(lambda m: GRBT(m,I_0=I,𝜌=𝜌,σo=σo,σn=σn,δo=δo,δn=δn,vo=vo,vn=vn,𝛼=𝛼),m_vals)
paramdata= pd.DataFrame.from_records(list(param), columns =['m','p','q','ICphi','ICn',
                                                            'πB','πA','πA0','πB0','πA1','πB1',
                                                            'S3','I3','D_vals','Uphi','Un','Ud'])
paramdata.to_csv('210313 GRBT benchmark, table.csv')
paramdata
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
#       m                   p  q         ICphi       ICn        πB        πA  \
# 0  0.15  0.7430000972067025  0  5.551115e-17 -0.169664  0.237529  0.000000
# 1  0.45                   1  0  4.028178e-01 -0.181642  0.818244  0.000000
# 2  0.75                   1  0  4.765463e-02 -0.190386  1.000000  0.666743
#
#         πA0       πB0  πA1       πB1        S3        I3    D_vals      Uphi  \
# 0  0.407192  0.000000    0  0.000000  0.909436  0.056200  0.001544  0.285035
# 1  1.000000  0.000626    0  0.000000  0.971725  0.009523  0.000445  0.981972
# 2  1.000000  1.000000    1  0.000391  0.982567  0.003963  0.000264  1.200078
#
#          Un        Ud
# ...

# %%
vo =0.5
vn=0.7
𝜌 = 1
σo=0.5
σn=0.7
𝛿o=0.5
𝛿n=0.7
I=0.01
𝛼=0.0138
m_vals=np.linspace(0.1,0.8,71)

param=map(lambda m: GRBT(m,I_0=I,𝜌=𝜌,σo=σo,σn=σn,δo=δo,δn=δn,vo=vo,vn=vn,𝛼=𝛼),m_vals)
paramdata= pd.DataFrame.from_records(list(param), columns =['m','p','q','ICphi','ICn',
                                                            'πB','πA','πA0','πB0','πA1','πB1',
                                                            'S3','I3','D_vals','Uphi','Un','Ud'])
paramdata.to_csv('210407 GRBT benchmark.csv')
paramdata
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
# C:\Users\user\anaconda3\lib\site-packages\scipy\optimize\nonlin.py:1001: RuntimeWarning: invalid value encountered in true_divide
#   d = v / vdot(df, v)
# C:\Users\user\code\model.py:904: RuntimeWarning: divide by zero encountered in double_scalars
#   πA0 = min(m/π2_0_coef,1)
# C:\Users\user\code\model.py:895: RuntimeWarning: divide by zero encountered in double_scalars
#   πB = min(m/πB_coef,1)
#        m                   p  q         ICphi       ICn        πB        πA  \
# 0   0.10  0.7017181960314013  0 -5.551115e-17 -0.113110  0.158354  0.000000
# 1   0.11  0.7096035225394287  0 -5.551115e-17 -0.124420  0.174189  0.000000
# ...

# %%
vo =0.5
vn=0.7
𝜌 = 0.5
σo=0.5
σn=0.7
𝛿o=0.5
𝛿n=0.7
I=0.01
𝛼=0.0138
m_vals=np.linspace(0.1,0.8,71)

param=map(lambda m: GRBT(m,I_0=I,𝜌=𝜌,σo=σo,σn=σn,δo=δo,δn=δn,vo=vo,vn=vn,𝛼=𝛼),m_vals)
paramdata= pd.DataFrame.from_records(list(param), columns =['m','p','q','ICphi','ICn',
                                                            'πB','πA','πA0','πB0','πA1','πB1',
                                                            'S3','I3','D_vals','Uphi','Un','Ud'])
paramdata.to_csv('210407 GRBT rho05.csv')
paramdata
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
# C:\Users\user\anaconda3\lib\site-packages\scipy\optimize\nonlin.py:1001: RuntimeWarning: invalid value encountered in true_divide
#   d = v / vdot(df, v)
# C:\Users\user\code\model.py:904: RuntimeWarning: divide by zero encountered in double_scalars
#   πA0 = min(m/π2_0_coef,1)
# C:\Users\user\anaconda3\lib\site-packages\scipy\optimize\nonlin.py:1001: RuntimeWarning: divide by zero encountered in true_divide
#   d = v / vdot(df, v)
#        m                   p  q         ICphi       ICn        πB        πA  \
# 0   0.10  0.8119372108262018  0 -2.775558e-17 -0.097755  0.136857  0.000000
# ...

# %%
vo =0.5
vn=0.7
𝜌 = 1
σo=0.5
σn=0.7
𝛿o=0.5
𝛿n=0.7
I=0.01
𝛼=0.35
m_vals=np.linspace(0.1,0.8,71)

param=map(lambda m: GRBT(m,I_0=I,𝜌=𝜌,σo=σo,σn=σn,δo=δo,δn=δn,vo=vo,vn=vn,𝛼=𝛼),m_vals)
paramdata= pd.DataFrame.from_records(list(param), columns =['m','p','q','ICphi','ICn',
                                                            'πB','πA','πA0','πB0','πA1','πB1',
                                                            'S3','I3','D_vals','Uphi','Un','Ud'])
paramdata.to_csv('210407 GRBT alpha035.csv')
paramdata
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
# C:\Users\user\anaconda3\lib\site-packages\scipy\optimize\nonlin.py:1001: RuntimeWarning: invalid value encountered in true_divide
#   d = v / vdot(df, v)
# C:\Users\user\code\model.py:904: RuntimeWarning: divide by zero encountered in double_scalars
#   πA0 = min(m/π2_0_coef,1)
# C:\Users\user\code\model.py:895: RuntimeWarning: divide by zero encountered in double_scalars
#   πB = min(m/πB_coef,1)
#        m                   p  q         ICphi       ICn        πB        πA  \
# 0   0.10  0.7008341919504768  0  0.000000e+00 -0.113252  0.158553  0.000000
# 1   0.11  0.7087304209021594  0  0.000000e+00 -0.124574  0.174403  0.000000
# ...

# %%
vo =0.5
vn=0.7
𝜌 = 1
σo=0.5
σn=0.7
𝛿o=0.5
𝛿n=0.7
I=0.01
𝛼=0.0138
m_vals=np.linspace(0.1,0.8,71)
𝛾=0.9

param=map(lambda m: GRBT(m,I_0=I,𝜌=𝜌,σo=σo,σn=σn,δo=δo,δn=δn,vo=vo,vn=vn,𝛼=𝛼,𝛾=𝛾),m_vals)
paramdata= pd.DataFrame.from_records(list(param), columns =['m','p','q','ICphi','ICn',
                                                            'πB','πA','πA0','πB0','πA1','πB1',
                                                            'S3','I3','D_vals','Uphi','Un','Ud'])
paramdata.to_csv('210410 GRBT gamma09.csv')
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
# C:\Users\user\code\model.py:904: RuntimeWarning: divide by zero encountered in double_scalars
#   πA0 = min(m/π2_0_coef,1)
# C:\Users\user\code\model.py:895: RuntimeWarning: divide by zero encountered in double_scalars
#   πB = min(m/πB_coef,1)

# %%
vo =0.5
vn=0.7
𝜌 = 1
σo=0.4
σn=0.6
𝛿o=0.5
𝛿n=0.7
I=0.01
𝛼=0.0138
m_vals=np.linspace(0.1,0.8,71)

param=map(lambda m: GRBT(m,I_0=I,𝜌=𝜌,σo=σo,σn=σn,δo=δo,δn=δn,vo=vo,vn=vn,𝛼=𝛼),m_vals)
paramdata= pd.DataFrame.from_records(list(param), columns =['m','p','q','ICphi','ICn',
                                                            'πB','πA','πA0','πB0','πA1','πB1',
                                                            'S3','I3','D_vals','Uphi','Un','Ud'])
paramdata.to_csv('210407 GRBT lowerinward.csv')
paramdata
# Out:
#        m                   p  q         ICphi       ICn        πB        πA  \
# 0   0.10  0.7017172791846567  0  5.551115e-17 -0.113110  0.158354  0.000000
# 1   0.11  0.7096025103532145  0 -1.110223e-16 -0.124421  0.174189  0.000000
# 2   0.12  0.7176669428506988  0 -5.551115e-17 -0.135731  0.190024  0.000000
# 3   0.13  0.7259167560332953  0  1.665335e-16 -0.147042  0.205859  0.000000
# 4   0.14  0.7343584166691057  0  5.551115e-17 -0.158353  0.221694  0.000000
# ..   ...                 ... ..           ...       ...       ...       ...
# 66  0.76                   1  0  3.012265e-02 -0.195387  1.000000  0.684287
# 67  0.77                   1  0  1.304116e-02 -0.200263  1.000000  0.701375
# 68  0.78                   0  0 -2.948545e-03 -0.160049  1.000000  0.780059
# 69  0.79                   0  0 -1.580666e-02 -0.165764  1.000000  0.790060
# 70  0.80                   0  0 -2.866477e-02 -0.171478  1.000000  0.800061
#
# ...

# %%
vo=0.4
vn=0.6
𝜌 = 1
σo=0.4
σn=0.6
𝛿o=0.5
𝛿n=0.7
I=0.01
𝛼=0.0138
m_vals=np.linspace(0.1,0.8,71)

param=map(lambda m: GRBT(m,I_0=I,𝜌=𝜌,σo=σo,σn=σn,δo=δo,δn=δn,vo=vo,vn=vn,𝛼=𝛼),m_vals)
paramdata= pd.DataFrame.from_records(list(param), columns =['m','p','q','ICphi','ICn',
                                                            'πB','πA','πA0','πB0','πA1','πB1',
                                                            'S3','I3','D_vals','Uphi','Un','Ud'])
paramdata.to_csv('210407 GRBT lowerinward link v.csv')
paramdata
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
# C:\Users\user\anaconda3\lib\site-packages\scipy\optimize\nonlin.py:1001: RuntimeWarning: invalid value encountered in true_divide
#   d = v / vdot(df, v)
# C:\Users\user\code\model.py:904: RuntimeWarning: divide by zero encountered in double_scalars
#   πA0 = min(m/π2_0_coef,1)
# C:\Users\user\code\model.py:895: RuntimeWarning: divide by zero encountered in double_scalars
#   πB = min(m/πB_coef,1)
#        m                   p  q         ICphi       ICn        πB        πA  \
# 0   0.10  0.6944069713046924  0  0.000000e+00 -0.106681  0.160021  0.000000
# 1   0.11  0.7022100607318764  0 -5.551115e-17 -0.117348  0.176023  0.000000
# ...

# %%
vo=0.5
vn=0.7
𝜌 = 1
σo=0.69
σn=0.7
𝛿o=0.69
𝛿n=0.7
I=0.01
𝛼=0.0138
m_vals=np.linspace(0.1,0.8,71)

param=map(lambda m: GRBT(m,I_0=I,𝜌=𝜌,σo=σo,σn=σn,δo=δo,δn=δn,vo=vo,vn=vn,𝛼=𝛼),m_vals)
paramdata= pd.DataFrame.from_records(list(param), columns =['m','p','q','ICphi','ICn',
                                                            'πB','πA','πA0','πB0','πA1','πB1',
                                                            'S3','I3','D_vals','Uphi','Un','Ud'])
paramdata.to_csv('210407 GRBT equalizing.csv')
paramdata
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
# C:\Users\user\anaconda3\lib\site-packages\scipy\optimize\nonlin.py:1001: RuntimeWarning: invalid value encountered in true_divide
#   d = v / vdot(df, v)
# C:\Users\user\code\model.py:904: RuntimeWarning: divide by zero encountered in double_scalars
#   πA0 = min(m/π2_0_coef,1)
# C:\Users\user\code\model.py:895: RuntimeWarning: divide by zero encountered in double_scalars
#   πB = min(m/πB_coef,1)
#        m                   p  q         ICphi       ICn        πB        πA  \
# 0   0.10  0.7017181960314013  0 -5.551115e-17 -0.113110  0.158354  0.000000
# 1   0.11  0.7096035225394287  0 -5.551115e-17 -0.124420  0.174189  0.000000
# ...

# %%
vo=0.69
vn=0.7
𝜌 = 1
σo=0.69
σn=0.7
𝛿o=0.69
𝛿n=0.7
I=0.01
𝛼=0.0138
m_vals=np.linspace(0.1,0.8,71)

param=map(lambda m: GRBT(m,I_0=I,𝜌=𝜌,σo=σo,σn=σn,δo=δo,δn=δn,vo=vo,vn=vn,𝛼=𝛼),m_vals)
paramdata= pd.DataFrame.from_records(list(param), columns =['m','p','q','ICphi','ICn',
                                                            'πB','πA','πA0','πB0','πA1','πB1',
                                                            'S3','I3','D_vals','Uphi','Un','Ud'])
paramdata.to_csv('210407 GRBT equalizing link v.csv')
paramdata
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
# C:\Users\user\anaconda3\lib\site-packages\scipy\optimize\nonlin.py:1001: RuntimeWarning: invalid value encountered in true_divide
#   d = v / vdot(df, v)
# C:\Users\user\anaconda3\lib\site-packages\scipy\optimize\nonlin.py:1001: RuntimeWarning: divide by zero encountered in true_divide
#   d = v / vdot(df, v)
# C:\Users\user\code\model.py:904: RuntimeWarning: divide by zero encountered in double_scalars
#   πA0 = min(m/π2_0_coef,1)
#        m                   p  q         ICphi       ICn        πB        πA  \
# 0   0.10  0.7389346032726686  0  0.000000e+00 -0.148230  0.150378  0.000000
# ...

# %%
vo =0.5
vn=0.7
𝜌 = 1
σo=0.5
σn=0.7
𝛿o=0.5
𝛿n=0.7
I=0.2
𝛼=0.0138
m_vals=np.linspace(0.1,0.8,71)

param=map(lambda m: GRBT(m,I_0=I,𝜌=𝜌,σo=σo,σn=σn,δo=δo,δn=δn,vo=vo,vn=vn,𝛼=𝛼),m_vals)
paramdata= pd.DataFrame.from_records(list(param), columns =['m','p','q','ICphi','ICn',
                                                            'πB','πA','πA0','πB0','πA1','πB1',
                                                            'S3','I3','D_vals','Uphi','Un','Ud'])
paramdata.to_csv('210407 GRBT I02.csv')
paramdata
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
# C:\Users\user\anaconda3\lib\site-packages\scipy\optimize\nonlin.py:1001: RuntimeWarning: invalid value encountered in true_divide
#   d = v / vdot(df, v)
# C:\Users\user\code\model.py:904: RuntimeWarning: divide by zero encountered in double_scalars
#   πA0 = min(m/π2_0_coef,1)
# C:\Users\user\code\model.py:895: RuntimeWarning: divide by zero encountered in double_scalars
#   πB = min(m/πB_coef,1)
#        m                   p  q         ICphi       ICn        πB        πA  \
# 0   0.10  0.7011336804694437  0  1.110223e-16 -0.113368  0.158715  0.000000
# 1   0.11  0.7090254118101041  0  5.551115e-17 -0.124702  0.174583  0.000000
# ...

# %%
vo =0.5
vn=0.7
𝜌 = 1
σo=0.5
σn=0.7
𝛿o=0.5
𝛿n=0.7
I=0.01
𝛼=0.0138
m_vals=np.linspace(0.1,0.8,71)
pattern='hop'

param=map(lambda m: GRBT_growth(m,I_0=I,𝜌=𝜌,σo=σo,σn=σn,δo=δo,δn=δn,vo=vo,vn=vn,𝛼=𝛼,pattern=pattern),m_vals)
paramdata= pd.DataFrame.from_records(list(param), columns =['m0','m1','m2','p','q','ICphi','ICn',
                                                            'πB','πA','πA0','πB0','πA1','πB1',
                                                            'S3','I3','D_vals','Uphi','Un','Ud'])
paramdata.to_csv('210407 GRBT hopgrowth.csv')
paramdata
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
# C:\Users\user\anaconda3\lib\site-packages\scipy\optimize\nonlin.py:1001: RuntimeWarning: invalid value encountered in true_divide
#   d = v / vdot(df, v)
# C:\Users\user\code\model.py:1301: RuntimeWarning: divide by zero encountered in double_scalars
#   πA0 = min(m2/π2_0_coef,1)
#       m0    m1      m2                   p  q         ICphi       ICn  \
# 0   0.10  0.10  0.1150  0.6649662369572733  0 -5.551115e-17 -0.119361
# 1   0.11  0.11  0.1265  0.6724385973351698  0 -5.551115e-17 -0.131297
# 2   0.12  0.12  0.1380  0.6800807747208499  0  0.000000e+00 -0.143233
# 3   0.13  0.13  0.1495  0.6878986248732198  0 -1.665335e-16 -0.155169
# ...

# %%
vo =0.5
vn=0.7
𝜌 = 1
σo=0.5
σn=0.7
𝛿o=0.5
𝛿n=0.7
I=0.01
𝛼=0.0138
m_vals=np.linspace(0.1,0.8,71)
pattern='stock'

param=map(lambda m: GRBT_growth(m,I_0=I,𝜌=𝜌,σo=σo,σn=σn,δo=δo,δn=δn,vo=vo,vn=vn,𝛼=𝛼,pattern=pattern),m_vals)
paramdata= pd.DataFrame.from_records(list(param), columns =['m0','m1','m2','p','q','ICphi','ICn',
                                                            'πB','πA','πA0','πB0','πA1','πB1',
                                                            'S3','I3','D_vals','Uphi','Un','Ud'])
paramdata.to_csv('210407 GRBT stock.csv')
paramdata
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
# C:\Users\user\anaconda3\lib\site-packages\scipy\optimize\nonlin.py:1001: RuntimeWarning: invalid value encountered in true_divide
#   d = v / vdot(df, v)
# C:\Users\user\code\model.py:1292: RuntimeWarning: divide by zero encountered in double_scalars
#   πB = min(m1/πB_coef,1)
#         m0    m1    m2                   p  q         ICphi       ICn  \
# 0   0.1150  0.10  0.10  0.7136130069095313  0  0.000000e+00 -0.113109
# 1   0.1265  0.11  0.11  0.7230090072015783  0  5.551115e-17 -0.124420
# 2   0.1380  0.12  0.12  0.7326556994959967  0  0.000000e+00 -0.135731
# 3   0.1495  0.13  0.13  0.7425632529569327  0  1.110223e-16 -0.147042
# ...
