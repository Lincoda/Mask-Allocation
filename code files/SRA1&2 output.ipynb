# %%
import numpy as np
import pandas as pd
from model import *

# %% [markdown]
# # SRA1

# %%
m_vals=np.linspace(0.15,0.75,3)
σo=0.5
σn=0.7
𝛿o=0.5
𝛿n=0.7
𝜌=1
vo=0.5
vn=0.7
𝛼=0.0138

result=map(lambda x: SRA1(x,I_0=0.01,σo=σo,σn=σn,𝛿o=𝛿o,𝛿n=𝛿n,vo=vo,vn=vn,𝜌=𝜌,𝛼=𝛼),m_vals)
result=list(result)
data=pd.DataFrame.from_records(result, columns =['func', 'π1','π2','S3','I3','Uphi','Un','Ud'])
data['m']=m_vals
data=data.rename(columns={'func':'D_vals'})


data.to_csv('210313 SRA1 benchmark, table.csv',index=False)
data
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
#      D_vals        π1        π2        S3        I3      Uphi        Un  \
# 0  0.001586  0.150011  0.150033  0.907044  0.058168  0.273784  1.398778
# 1  0.000574  0.450034  0.450079  0.964571  0.014895  0.753821  1.728804
# 2  0.000279  0.750057  0.750106  0.981698  0.004550  1.143832  1.968803
#
#          Ud     m
# 0  1.124994  0.15
# 1  0.974983  0.45
# 2  0.824971  0.75

# %%
m_vals=np.linspace(0.1,0.8,71)
σo=0.5
σn=0.7
𝛿o=0.5
𝛿n=0.7
𝜌=1
vo=0.5
vn=0.7
𝛼=0.0138

result=map(lambda x: SRA1(x,I_0=0.01,σo=σo,σn=σn,𝛿o=𝛿o,𝛿n=𝛿n,vo=vo,vn=vn,𝜌=𝜌,𝛼=𝛼),m_vals)
result=list(result)
data=pd.DataFrame.from_records(result, columns =['func', 'π1','π2','S3','I3','Uphi','Un','Ud'])
data['m']=m_vals
data=data.rename(columns={'func':'D_vals'})


data.to_csv('210407 SRA1 benchmark.csv',index=False)
data
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
#       D_vals        π1        π2        S3        I3      Uphi        Un  \
# 0   0.001903  0.100008  0.100023  0.888764  0.072903  0.185024  1.335020
# 1   0.001835  0.110008  0.110025  0.892713  0.069697  0.202976  1.347972
# 2   0.001769  0.120009  0.120027  0.896510  0.066625  0.220828  1.360823
# 3   0.001706  0.130010  0.130029  0.900161  0.063683  0.238580  1.373575
# 4   0.001645  0.140011  0.140031  0.903671  0.060865  0.256232  1.386227
# ..       ...       ...       ...       ...       ...       ...       ...
# 66  0.000274  0.760058  0.760107  0.981995  0.004401  1.155282  1.975253
# ...

# %%
m_vals=np.linspace(0.1,0.8,71)
σo=0.5
σn=0.7
𝛿o=0.5
𝛿n=0.7
𝜌=0.5
vo=0.5
vn=0.7
𝛼=0.0138

result=map(lambda x: SRA1(x,I_0=0.01,σo=σo,σn=σn,𝛿o=𝛿o,𝛿n=𝛿n,vo=vo,vn=vn,𝜌=𝜌,𝛼=𝛼),m_vals)
result=list(result)
data=pd.DataFrame.from_records(result, columns =['func', 'π1','π2','S3','I3','Uphi','Un','Ud'])
data['m']=m_vals
data=data.rename(columns={'func':'D_vals'})


data.to_csv('210407 SRA1 rho05.csv',index=False)
data
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
#       D_vals        π1        π2        S3        I3      Uphi        Un  \
# 0   0.001903  0.100008  0.100023  0.888764  0.072903  0.063757  0.988755
# 1   0.001835  0.110008  0.110025  0.892713  0.069697  0.069995  0.992493
# 2   0.001769  0.120009  0.120027  0.896510  0.066625  0.076209  0.996206
# 3   0.001706  0.130010  0.130029  0.900161  0.063683  0.082397  0.999894
# 4   0.001645  0.140011  0.140031  0.903671  0.060865  0.088560  1.003557
# ..       ...       ...       ...       ...       ...       ...       ...
# 66  0.000274  0.760058  0.760107  0.981995  0.004401  0.421831  1.181816
# ...

# %%
m_vals=np.linspace(0.1,0.8,71)
σo=0.5
σn=0.7
𝛿o=0.5
𝛿n=0.7
𝜌=1
vo=0.5
vn=0.7
𝛼=0.35

result=map(lambda x: SRA1(x,I_0=0.01,σo=σo,σn=σn,𝛿o=𝛿o,𝛿n=𝛿n,vo=vo,vn=vn,𝜌=𝜌,𝛼=𝛼),m_vals)
result=list(result)
data=pd.DataFrame.from_records(result, columns =['func', 'π1','π2','S3','I3','Uphi','Un','Ud'])
data['m']=m_vals
data=data.rename(columns={'func':'D_vals'})

data.to_csv('210407 SRA1 alpha035.csv',index=False)
data
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
#       D_vals        π1        π2        S3        I3      Uphi        Un  \
# 0   0.048262  0.100008  0.100404  0.888796  0.072872  0.185271  1.335267
# 1   0.046528  0.110008  0.110439  0.892746  0.069664  0.203243  1.348239
# 2   0.044858  0.120009  0.120474  0.896544  0.066592  0.221113  1.361109
# 3   0.043249  0.130010  0.130507  0.900195  0.063649  0.238883  1.373878
# 4   0.041699  0.140011  0.140540  0.903705  0.060831  0.256552  1.386547
# ..       ...       ...       ...       ...       ...       ...       ...
# 66  0.006958  0.760058  0.761311  0.981999  0.004398  1.155667  1.975638
# ...

# %%
m_vals=np.linspace(0.1,0.8,71)
σo=0.5
σn=0.7
𝛿o=0.5
𝛿n=0.7
𝜌=1
vo=0.5
vn=0.7
𝛼=0.35
𝛾=0.9

result=map(lambda x: SRA1(x,I_0=0.01,σo=σo,σn=σn,𝛿o=𝛿o,𝛿n=𝛿n,vo=vo,vn=vn,𝜌=𝜌,𝛼=𝛼,𝛾=𝛾),m_vals)
result=list(result)
data=pd.DataFrame.from_records(result, columns =['func', 'π1','π2','S3','I3','Uphi','Un','Ud'])
data['m']=m_vals
data=data.rename(columns={'func':'D_vals'})

data.to_csv('210410 SRA1 gamma09.csv',index=False)
data
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
#       D_vals        π1        π2        S3        I3      Uphi        Un  \
# 0   0.034075  0.100008  0.100404  0.910973  0.040754  0.185271  1.335267
# 1   0.032822  0.110008  0.110439  0.914149  0.038607  0.203243  1.348239
# 2   0.031619  0.120009  0.120474  0.917197  0.036563  0.221113  1.361109
# 3   0.030465  0.130010  0.130507  0.920123  0.034616  0.238883  1.373878
# 4   0.029357  0.140011  0.140540  0.922931  0.032764  0.256552  1.386547
# ..       ...       ...       ...       ...       ...       ...       ...
# 66  0.005647  0.760058  0.761311  0.984026  0.000708  1.155667  1.975638
# ...

# %%
m_vals=np.linspace(0.1,0.8,71)
σo=0.4
σn=0.6
𝛿o=0.5
𝛿n=0.7
𝜌=1
vo=0.5
vn=0.7
𝛼=0.0138

result=map(lambda x: SRA1(x,I_0=0.01,σo=σo,σn=σn,𝛿o=𝛿o,𝛿n=𝛿n,vo=vo,vn=vn,𝜌=𝜌,𝛼=𝛼),m_vals)
result=list(result)
data=pd.DataFrame.from_records(result, columns =['func', 'π1','π2','S3','I3','Uphi','Un','Ud'])
data['m']=m_vals
data=data.rename(columns={'func':'D_vals'})

data.to_csv('210407 SRA1 lowerinward.csv',index=False)
data
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
#       D_vals        π1        π2        S3        I3      Uphi        Un  \
# 0   0.002148  0.100008  0.100023  0.885650  0.075451  0.185024  1.335020
# 1   0.002077  0.110008  0.110025  0.889409  0.072392  0.202976  1.347972
# 2   0.002008  0.120009  0.120028  0.893034  0.069451  0.220828  1.360823
# 3   0.001942  0.130010  0.130030  0.896529  0.066625  0.238580  1.373575
# 4   0.001878  0.140011  0.140032  0.899899  0.063910  0.256232  1.386227
# ..       ...       ...       ...       ...       ...       ...       ...
# 66  0.000330  0.760058  0.760111  0.979806  0.005638  1.155283  1.975254
# ...

# %%
m_vals=np.linspace(0.1,0.8,71)
σo=0.4
σn=0.6
𝛿o=0.5
𝛿n=0.7
𝜌=1
vo=0.4
vn=0.6
𝛼=0.0138

result=map(lambda x: SRA1(x,I_0=0.01,σo=σo,σn=σn,𝛿o=𝛿o,𝛿n=𝛿n,vo=vo,vn=vn,𝜌=𝜌,𝛼=𝛼),m_vals)
result=list(result)
data=pd.DataFrame.from_records(result, columns =['func', 'π1','π2','S3','I3','Uphi','Un','Ud'])
data['m']=m_vals
data=data.rename(columns={'func':'D_vals'})

data.to_csv('210407 SRA1 lowerinward link v.csv',index=False)
data
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
#       D_vals        π1        π2        S3        I3      Uphi        Un  \
# 0   0.002148  0.100008  0.100023  0.885650  0.075451  0.156020  1.116017
# 1   0.002077  0.110008  0.110025  0.889409  0.072392  0.171182  1.127179
# 2   0.002008  0.120009  0.120028  0.893034  0.069451  0.186264  1.138260
# 3   0.001942  0.130010  0.130030  0.896529  0.066625  0.201266  1.149262
# 4   0.001878  0.140011  0.140032  0.899899  0.063910  0.216187  1.160183
# ..       ...       ...       ...       ...       ...       ...       ...
# 66  0.000330  0.760058  0.760111  0.979806  0.005638  0.985033  1.681010
# ...

# %%
m_vals=np.linspace(0.1,0.8,71)
σo=0.69
σn=0.7
𝛿o=0.69
𝛿n=0.7
𝜌=1
vo=0.5
vn=0.7
𝛼=0.0138

result=map(lambda x: SRA1(x,I_0=0.01,σo=σo,σn=σn,𝛿o=𝛿o,𝛿n=𝛿n,vo=vo,vn=vn,𝜌=𝜌,𝛼=𝛼),m_vals)
result=list(result)
data=pd.DataFrame.from_records(result, columns =['func', 'π1','π2','S3','I3','Uphi','Un','Ud'])
data['m']=m_vals
data=data.rename(columns={'func':'D_vals'})

data.to_csv('210407 SRA1 equalizing.csv',index=False)
data
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
#       D_vals        π1        π2        S3        I3      Uphi        Un  \
# 0   0.001840  0.100008  0.100023  0.892349  0.069784  0.185024  1.335020
# 1   0.001769  0.110008  0.110025  0.896483  0.066423  0.202976  1.347972
# 2   0.001700  0.120009  0.120027  0.900440  0.063219  0.220828  1.360823
# 3   0.001634  0.130010  0.130029  0.904229  0.060165  0.238580  1.373575
# 4   0.001570  0.140011  0.140031  0.907855  0.057254  0.256232  1.386227
# ..       ...       ...       ...       ...       ...       ...       ...
# 66  0.000261  0.760058  0.760107  0.982735  0.003865  1.155282  1.975253
# ...

# %%
m_vals=np.linspace(0.1,0.8,71)
σo=0.69
σn=0.7
𝛿o=0.69
𝛿n=0.7
𝜌=1
vo=0.69
vn=0.7
𝛼=0.0138

result=map(lambda x: SRA1(x,I_0=0.01,σo=σo,σn=σn,𝛿o=𝛿o,𝛿n=𝛿n,vo=vo,vn=vn,𝜌=𝜌,𝛼=𝛼),m_vals)
result=list(result)
data=pd.DataFrame.from_records(result, columns =['func', 'π1','π2','S3','I3','Uphi','Un','Ud'])
data['m']=m_vals
data=data.rename(columns={'func':'D_vals'})

data.to_csv('210407 SRA1 equalizing link v.csv',index=False)
data
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
#       D_vals        π1        π2        S3        I3      Uphi        Un  \
# 0   0.001840  0.100008  0.100023  0.892349  0.069784  0.202125  1.523119
# 1   0.001769  0.110008  0.110025  0.896483  0.066423  0.221578  1.535672
# 2   0.001700  0.120009  0.120027  0.900440  0.063219  0.240893  1.548087
# 3   0.001634  0.130010  0.130029  0.904229  0.060165  0.260070  1.560363
# 4   0.001570  0.140011  0.140031  0.907855  0.057254  0.279109  1.572501
# ..       ...       ...       ...       ...       ...       ...       ...
# 66  0.000261  0.760058  0.760107  0.982735  0.003865  1.189925  2.055485
# ...

# %%
m_vals=np.linspace(0.1,0.8,71)
σo=0.5
σn=0.7
𝛿o=0.5
𝛿n=0.7
𝜌=1
vo=0.5
vn=0.7
𝛼=0.0138

result=map(lambda x: SRA1(x,I_0=0.2,σo=σo,σn=σn,𝛿o=𝛿o,𝛿n=𝛿n,vo=vo,vn=vn,𝜌=𝜌,𝛼=𝛼),m_vals)
result=list(result)
data=pd.DataFrame.from_records(result, columns =['func', 'π1','π2','S3','I3','Uphi','Un','Ud'])
data['m']=m_vals
data=data.rename(columns={'func':'D_vals'})


data.to_csv('210407 SRA1 I02.csv',index=False)
data
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
#       D_vals        π1        π2        S3        I3      Uphi        Un  \
# 0   0.012586  0.100152  0.100418  0.098735  0.360059  0.185447  1.335371
# 1   0.012437  0.110167  0.110457  0.110738  0.355362  0.203436  1.348353
# 2   0.012285  0.120183  0.120495  0.122945  0.350349  0.221325  1.361234
# 3   0.012130  0.130198  0.130532  0.135320  0.345059  0.239113  1.374014
# 4   0.011973  0.140213  0.140569  0.147831  0.339523  0.256799  1.386693
# ..       ...       ...       ...       ...       ...       ...       ...
# 66  0.004584  0.761157  0.762058  0.684613  0.064216  1.156806  1.976228
# ...

# %%
m_vals=np.linspace(0.1,0.8,71)
σo=0.5
σn=0.7
𝛿o=0.5
𝛿n=0.7
𝜌=1
vo=0.5
vn=0.7
𝛼=0.0138

result=map(lambda x: SRA1_mchange(x,I_0=0.01,σo=σo,σn=σn,𝛿o=𝛿o,𝛿n=𝛿n,pattern='stock'),m_vals)
result=list(result)
data=pd.DataFrame.from_records(result, columns =['func', 'π1','π2','S3','I3','Uphi','Un','Ud'])
data['m']=m_vals
data=data.rename(columns={'func':'D_vals'})

data.to_csv('210407 SRA1 stock.csv',index=False)
data
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
#       D_vals        π1        π2        S3        I3      Uphi        Un  \
# 0   0.001860  0.100008  0.100023  0.891345  0.071078  0.185024  1.335020
# 1   0.001789  0.110008  0.110025  0.895452  0.067770  0.202976  1.347971
# 2   0.001721  0.120009  0.120027  0.899394  0.064609  0.220828  1.360823
# 3   0.001655  0.130010  0.130029  0.903176  0.061588  0.238580  1.373575
# 4   0.001592  0.140011  0.140031  0.906804  0.058701  0.256231  1.386226
# ..       ...       ...       ...       ...       ...       ...       ...
# 66  0.000241  0.760058  0.760100  0.984056  0.003629  1.155279  1.975250
# ...

# %%
m_vals=np.linspace(0.1,0.8,71)
σo=0.5
σn=0.7
𝛿o=0.5
𝛿n=0.7
𝜌=1
vo=0.5
vn=0.7
𝛼=0.0138

result=map(lambda x: SRA1_mchange(x,I_0=0.01,σo=σo,σn=σn,𝛿o=𝛿o,𝛿n=𝛿n,pattern='hop'),m_vals)
result=list(result)
data=pd.DataFrame.from_records(result, columns =['func', 'π1','π2','S3','I3','Uphi','Un','Ud'])
data['m']=m_vals
data=data.rename(columns={'func':'D_vals'})

data.to_csv('210407 SRA1 hopgrowth.csv',index=False)
data
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
#       D_vals        π1        π2        S3        I3      Uphi        Un  \
# 0   0.001881  0.100008  0.115027  0.889985  0.071683  0.194776  1.344772
# 1   0.001812  0.110008  0.126529  0.893996  0.068414  0.213621  1.358617
# 2   0.001745  0.120009  0.138031  0.897847  0.065288  0.232350  1.372346
# 3   0.001680  0.130010  0.149534  0.901544  0.062300  0.250965  1.385960
# 4   0.001619  0.140011  0.161036  0.905093  0.059443  0.269465  1.399459
# ..       ...       ...       ...       ...       ...       ...       ...
# 66  0.000268  0.760058  0.874123  0.982307  0.004090  1.191763  2.011735
# ...

# %% [markdown]
# # SRA2

# %%
m_vals=np.linspace(0.15,0.75,3)
σo=0.5
σn=0.7
𝛿o=0.5
𝛿n=0.7
𝜌=1
vo=0.5
vn=0.7
𝛼=0.0138

result=map(lambda x: SRA2(x,I_0=0.01,σo=σo,σn=σn,𝛿o=𝛿o,𝛿n=𝛿n,vo=vo,vn=vn,𝜌=𝜌,𝛼=𝛼),m_vals)
result=list(result)
data=pd.DataFrame.from_records(result, columns =['func','π1','π20','π21','S3','I3','Uphi','Un','Ud'])
data['m']=m_vals
data=data.rename(columns={'func':'D_vals'})


data.to_csv('210313 SRA2 benchmark, table.csv',index=False)
data
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
#      D_vals        π1       π20       π21        S3        I3      Uphi  \
# 0  0.001562  0.150011  0.176512  0.000000  0.908344  0.056868  0.285037
# 1  0.000512  0.450034  0.818377  0.000000  0.967800  0.011666  0.855097
# 2  0.000273  0.750057  1.000000  0.666834  0.982012  0.004236  1.175061
#
#          Un        Ud     m
# 0  1.410031  1.124994  0.15
# 1  1.830079  0.974983  0.45
# 2  2.000033  0.824971  0.75

# %%
m_vals=np.linspace(0.1,0.8,71)
σo=0.5
σn=0.7
𝛿o=0.5
𝛿n=0.7
𝜌=1
vo=0.5
vn=0.7
𝛼=0.0138

result=map(lambda x: SRA2(x,I_0=0.01,σo=σo,σn=σn,𝛿o=𝛿o,𝛿n=𝛿n,vo=vo,vn=vn,𝜌=𝜌,𝛼=𝛼),m_vals)
result=list(result)
data=pd.DataFrame.from_records(result, columns =['func','π1','π20','π21','S3','I3','Uphi','Un','Ud'])
data['m']=m_vals
data=data.rename(columns={'func':'D_vals'})


data.to_csv('210407 SRA2 benchmark.csv',index=False)
data
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
#       D_vals        π1       π20       π21        S3        I3      Uphi  \
# 0   0.001891  0.100008  0.111138  0.000000  0.889462  0.072205  0.190025
# 1   0.001820  0.110008  0.123625  0.000000  0.893527  0.068883  0.209028
# 2   0.001752  0.120009  0.136396  0.000000  0.897443  0.065693  0.228030
# 3   0.001686  0.130010  0.149461  0.000000  0.901215  0.062629  0.247032
# 4   0.001623  0.140011  0.162829  0.000000  0.904847  0.059689  0.266035
# ..       ...       ...       ...       ...       ...       ...       ...
# 66  0.000269  0.760058  1.000000  0.684375  0.982275  0.004122  1.184062
# ...

# %%
m_vals=np.linspace(0.1,0.8,71)
σo=0.5
σn=0.7
𝛿o=0.5
𝛿n=0.7
𝜌=0.5
vo=0.5
vn=0.7
𝛼=0.0138

result=map(lambda x: SRA2(x,I_0=0.01,σo=σo,σn=σn,𝛿o=𝛿o,𝛿n=𝛿n,vo=vo,vn=vn,𝜌=𝜌,𝛼=𝛼),m_vals)
result=list(result)
data=pd.DataFrame.from_records(result, columns =['func','π1','π20','π21','S3','I3','Uphi','Un','Ud'])
data['m']=m_vals
data=data.rename(columns={'func':'D_vals'})

data.to_csv('210407 SRA2 rho05.csv',index=False)
data
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
#       D_vals        π1       π20       π21        S3        I3      Uphi  \
# 0   0.001891  0.100008  0.111138  0.000000  0.889462  0.072205  0.065008
# 1   0.001820  0.110008  0.123625  0.000000  0.893527  0.068883  0.071508
# 2   0.001752  0.120009  0.136396  0.000000  0.897443  0.065693  0.078009
# 3   0.001686  0.130010  0.149461  0.000000  0.901215  0.062629  0.084510
# 4   0.001623  0.140011  0.162829  0.000000  0.904847  0.059689  0.091011
# ..       ...       ...       ...       ...       ...       ...       ...
# 66  0.000269  0.760058  1.000000  0.684375  0.982275  0.004122  0.429026
# ...

# %%
m_vals=np.linspace(0.1,0.8,71)
σo=0.5
σn=0.7
𝛿o=0.5
𝛿n=0.7
𝜌=1
vo=0.5
vn=0.7
𝛼=0.35

result=map(lambda x: SRA2(x,I_0=0.01,σo=σo,σn=σn,𝛿o=𝛿o,𝛿n=𝛿n,vo=vo,vn=vn,𝜌=𝜌,𝛼=𝛼),m_vals)
result=list(result)
data=pd.DataFrame.from_records(result, columns =['func','π1','π20','π21','S3','I3','Uphi','Un','Ud'])
data['m']=m_vals
data=data.rename(columns={'func':'D_vals'})


data.to_csv('210407 SRA2 alpha035.csv',index=False)
data
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
#       D_vals        π1       π20       π21        S3        I3      Uphi  \
# 0   0.047938  0.100008  0.111561  0.000000  0.889496  0.072172  0.190292
# 1   0.046150  0.110008  0.124090  0.000000  0.893562  0.068848  0.209317
# 2   0.044423  0.120009  0.136903  0.000000  0.897479  0.065656  0.228342
# 3   0.042756  0.130010  0.150010  0.000000  0.901252  0.062592  0.247367
# 4   0.041147  0.140011  0.163420  0.000000  0.904886  0.059650  0.266391
# ..       ...       ...       ...       ...       ...       ...       ...
# 66  0.006819  0.760058  1.000000  0.685960  0.982277  0.004120  1.184303
# ...

# %%
m_vals=np.linspace(0.1,0.8,71)
σo=0.5
σn=0.7
𝛿o=0.5
𝛿n=0.7
𝜌=1
vo=0.5
vn=0.7
𝛼=0.35

result=map(lambda x: SRA2(x,I_0=0.01,σo=σo,σn=σn,𝛿o=𝛿o,𝛿n=𝛿n,vo=vo,vn=vn,𝜌=𝜌,𝛼=𝛼,𝛾=𝛾),m_vals)
result=list(result)
data=pd.DataFrame.from_records(result, columns =['func','π1','π20','π21','S3','I3','Uphi','Un','Ud'])
data['m']=m_vals
data=data.rename(columns={'func':'D_vals'})

data.to_csv('210410 SRA2 gamma09.csv',index=False)
data
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
#       D_vals        π1       π20       π21        S3        I3      Uphi  \
# 0   0.033865  0.100008  0.111718  0.000000  0.911476  0.040251  0.190391
# 1   0.032579  0.110008  0.124261  0.000000  0.914732  0.038025  0.209424
# 2   0.031341  0.120009  0.137088  0.000000  0.917861  0.035900  0.228456
# 3   0.030152  0.130010  0.150208  0.000000  0.920868  0.033871  0.247488
# 4   0.029010  0.140011  0.163632  0.000000  0.923758  0.031937  0.266518
# ..       ...       ...       ...       ...       ...       ...       ...
# 66  0.005604  0.760058  1.000000  0.685903  0.984125  0.000608  1.184294
# ...

# %%
m_vals=np.linspace(0.1,0.8,71)
σo=0.4
σn=0.6
𝛿o=0.5
𝛿n=0.7
𝜌=1
vo=0.5
vn=0.7
𝛼=0.0138

result=map(lambda x: SRA2(x,I_0=0.01,σo=σo,σn=σn,𝛿o=𝛿o,𝛿n=𝛿n,vo=vo,vn=vn,𝜌=𝜌,𝛼=𝛼),m_vals)
result=list(result)
data=pd.DataFrame.from_records(result, columns =['func','π1','π20','π21','S3','I3','Uphi','Un','Ud'])
data['m']=m_vals
data=data.rename(columns={'func':'D_vals'})


data.to_csv('210407 SRA2 lowerinward.csv',index=False)
data
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
#       D_vals        π1       π20       π21        S3        I3      Uphi  \
# 0   0.002135  0.100008  0.111138  0.000000  0.886294  0.074808  0.190025
# 1   0.002062  0.110008  0.123625  0.000000  0.890162  0.071639  0.209028
# 2   0.001991  0.120009  0.136396  0.000000  0.893899  0.068586  0.228030
# 3   0.001922  0.130010  0.149461  0.000000  0.897510  0.065644  0.247033
# 4   0.001855  0.140011  0.162830  0.000000  0.900998  0.062811  0.266035
# ..       ...       ...       ...       ...       ...       ...       ...
# 66  0.000322  0.760058  1.000000  0.684380  0.980147  0.005297  1.184063
# ...

# %%
m_vals=np.linspace(0.1,0.8,71)
σo=0.4
σn=0.6
𝛿o=0.5
𝛿n=0.7
𝜌=1
vo=0.4
vn=0.6
𝛼=0.0138

result=map(lambda x: SRA2(x,I_0=0.01,σo=σo,σn=σn,𝛿o=𝛿o,𝛿n=𝛿n,vo=vo,vn=vn,𝜌=𝜌,𝛼=𝛼),m_vals)
result=list(result)
data=pd.DataFrame.from_records(result, columns =['func','π1','π20','π21','S3','I3','Uphi','Un','Ud'])
data['m']=m_vals
data=data.rename(columns={'func':'D_vals'})


data.to_csv('210407 SRA2 lowerinward link v.csv',index=False)
data
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
#       D_vals        π1       π20       π21        S3        I3      Uphi  \
# 0   0.002135  0.100008  0.111138  0.000000  0.886294  0.074808  0.160022
# 1   0.002062  0.110008  0.123625  0.000000  0.890162  0.071639  0.176024
# 2   0.001991  0.120009  0.136396  0.000000  0.893899  0.068586  0.192026
# 3   0.001922  0.130010  0.149461  0.000000  0.897510  0.065644  0.208028
# 4   0.001855  0.140011  0.162830  0.000000  0.900998  0.062811  0.224030
# ..       ...       ...       ...       ...       ...       ...       ...
# 66  0.000322  0.760058  1.000000  0.684380  0.980147  0.005297  1.008057
# ...

# %%
m_vals=np.linspace(0.1,0.8,71)
σo=0.69
σn=0.7
𝛿o=0.69
𝛿n=0.7
𝜌=1
vo=0.69
vn=0.7
𝛼=0.0138

result=map(lambda x: SRA2(x,I_0=0.01,σo=σo,σn=σn,𝛿o=𝛿o,𝛿n=𝛿n,vo=vo,vn=vn,𝜌=𝜌,𝛼=𝛼),m_vals)
result=list(result)
data=pd.DataFrame.from_records(result, columns =['func','π1','π20','π21','S3','I3','Uphi','Un','Ud'])
data['m']=m_vals
data=data.rename(columns={'func':'D_vals'})


data.to_csv('210407 SRA2 equalizing.csv',index=False)
data
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
#       D_vals        π1       π20       π21        S3        I3      Uphi  \
# 0   0.001825  0.100008  0.111138  0.000000  0.893193  0.068940  0.209027
# 1   0.001751  0.110008  0.123625  0.000000  0.897463  0.065443  0.229929
# 2   0.001679  0.120009  0.136396  0.000000  0.901559  0.062100  0.250832
# 3   0.001611  0.130010  0.149461  0.000000  0.905489  0.058905  0.271734
# 4   0.001544  0.140011  0.162829  0.000000  0.909256  0.055852  0.292637
# ..       ...       ...       ...       ...       ...       ...       ...
# 66  0.000255  0.760058  1.000000  0.684375  0.983026  0.003573  1.229642
# ...

# %%
m_vals=np.linspace(0.1,0.8,71)
σo=0.69
σn=0.7
𝛿o=0.69
𝛿n=0.7
𝜌=1
vo=0.69
vn=0.7
𝛼=0.0138

result=map(lambda x: SRA2(x,I_0=0.01,σo=σo,σn=σn,𝛿o=𝛿o,𝛿n=𝛿n,vo=vo,vn=vn,𝜌=𝜌,𝛼=𝛼),m_vals)
result=list(result)
data=pd.DataFrame.from_records(result, columns =['func','π1','π20','π21','S3','I3','Uphi','Un','Ud'])
data['m']=m_vals
data=data.rename(columns={'func':'D_vals'})


data.to_csv('210407 SRA2 equalizing link v.csv',index=False)
data
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
#       D_vals        π1       π20       π21        S3        I3      Uphi  \
# 0   0.001825  0.100008  0.111138  0.000000  0.893193  0.068940  0.209027
# 1   0.001751  0.110008  0.123625  0.000000  0.897463  0.065443  0.229929
# 2   0.001679  0.120009  0.136396  0.000000  0.901559  0.062100  0.250832
# 3   0.001611  0.130010  0.149461  0.000000  0.905489  0.058905  0.271734
# 4   0.001544  0.140011  0.162829  0.000000  0.909256  0.055852  0.292637
# ..       ...       ...       ...       ...       ...       ...       ...
# 66  0.000255  0.760058  1.000000  0.684375  0.983026  0.003573  1.229642
# ...

# %%
m_vals=np.linspace(0.1,0.8,71)
σo=0.5
σn=0.7
𝛿o=0.5
𝛿n=0.7
𝜌=1
vo=0.5
vn=0.7
𝛼=0.0138

result=map(lambda x: SRA2(x,I_0=0.2,σo=σo,σn=σn,𝛿o=𝛿o,𝛿n=𝛿n,vo=vo,vn=vn,𝜌=𝜌,𝛼=𝛼),m_vals)
result=list(result)
data=pd.DataFrame.from_records(result, columns =['func','π1','π20','π21','S3','I3','Uphi','Un','Ud'])
data['m']=m_vals
data=data.rename(columns={'func':'D_vals'})


data.to_csv('210407 SRA2 I02.csv',index=False)
data
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
#       D_vals        π1       π20       π21        S3        I3      Uphi  \
# 0   0.012564  0.100152  0.111595  0.000000  0.100461  0.358334  0.190476
# 1   0.012410  0.110167  0.124132  0.000000  0.112868  0.353231  0.209521
# 2   0.012252  0.120183  0.136955  0.000000  0.125522  0.347772  0.228566
# 3   0.012091  0.130198  0.150071  0.000000  0.138386  0.341992  0.247610
# 4   0.011927  0.140213  0.163493  0.000000  0.151426  0.335928  0.266654
# ..       ...       ...       ...       ...       ...       ...       ...
# 66  0.004532  0.761157  1.000000  0.687394  0.687682  0.061147  1.185221
# ...

# %%
m_vals=np.linspace(0.1,0.8,71)
σo=0.5
σn=0.7
𝛿o=0.5
𝛿n=0.7
𝜌=1
vo=0.5
vn=0.7
𝛼=0.0138

result=map(lambda x: SRA2_mchange(x,I_0=0.01,σo=σo,σn=σn,𝛿o=𝛿o,𝛿n=𝛿n,pattern='stock'),m_vals)
result=list(result)
data=pd.DataFrame.from_records(result, columns =['func','π1','π20','π21','S3','I3','Uphi','Un','Ud'])
data['m']=m_vals
data=data.rename(columns={'func':'D_vals'})

data.to_csv('210407 SRA2 stock.csv',index=False)
data
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
#       D_vals        π1       π20       π21        S3        I3      Uphi  \
# 0   0.001848  0.100008  0.111137  0.000000  0.892025  0.070398  0.190025
# 1   0.001775  0.110008  0.123625  0.000000  0.896243  0.066980  0.209028
# 2   0.001704  0.120009  0.136396  0.000000  0.900298  0.063705  0.228030
# 3   0.001636  0.130010  0.149460  0.000000  0.904194  0.060569  0.247032
# 4   0.001571  0.140011  0.162829  0.000000  0.907938  0.057567  0.266034
# ..       ...       ...       ...       ...       ...       ...       ...
# 66  0.000237  0.760058  1.000000  0.684366  0.984281  0.003405  1.184060
# ...

# %%
m_vals=np.linspace(0.1,0.8,71)
σo=0.5
σn=0.7
𝛿o=0.5
𝛿n=0.7
𝜌=1
vo=0.5
vn=0.7
𝛼=0.0138

result=map(lambda x: SRA2_mchange(x,I_0=0.01,σo=σo,σn=σn,𝛿o=𝛿o,𝛿n=𝛿n,pattern='hop'),m_vals)
result=list(result)
data=pd.DataFrame.from_records(result, columns =['func','π1','π20','π21','S3','I3','Uphi','Un','Ud'])
data['m']=m_vals
data=data.rename(columns={'func':'D_vals'})

data.to_csv('210407 SRA2 hopgrowth.csv',index=False)
data
# Out:
# C:\Users\user\code\model.py:179: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
#       D_vals        π1       π20       π21        S3        I3      Uphi  \
# 0   0.001867  0.100008  0.127808  0.000000  0.890778  0.070890  0.200528
# 1   0.001795  0.110008  0.142169  0.000000  0.894919  0.067491  0.220580
# 2   0.001725  0.120009  0.156856  0.000000  0.898904  0.064231  0.240633
# 3   0.001658  0.130010  0.171880  0.000000  0.902737  0.061107  0.260686
# 4   0.001594  0.140011  0.187254  0.000000  0.906423  0.058113  0.280738
# ..       ...       ...       ...       ...       ...       ...       ...
# 66  0.000266  0.760058  1.000000  0.834385  0.982441  0.003955  1.206865
# ...
