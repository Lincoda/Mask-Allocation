# %%
from model_quarantine import *
import numpy as np
import pandas as pd

# %%
vo =0.5
vn=0.7
𝜌 = 1
σo=0.5
σn=0.7
𝛿o=0.5
𝛿n=0.7
I=0.01
𝛼=0.0138
m_vals=np.linspace(0.1,0.8,71)

param=map(lambda m: GRBT_Qua(m,I_0=I,𝜌=𝜌,σo=σo,σn=σn,δo=δo,δn=δn,vo=vo,vn=vn),m_vals)
paramdata= pd.DataFrame.from_records(list(param), columns =['m','p','q','ICphi','ICn',
                                                            'πB','πA','πA0','πB0','πA1','πB1',
                                                            'S4','I4','D_vals','Uphi','Un','Ud'])
paramdata.to_csv('210407 GRBT quarantine.csv',index=False)
paramdata
# Out:
# C:\Users\coolcold1898\Dropbox\COVID-19-Mask\要上傳的程式碼\code files\model_quarantine.py:183: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nI_I,nR_I,nR,nD]))
# C:\Users\coolcold1898\Dropbox\COVID-19-Mask\要上傳的程式碼\code files\model_quarantine.py:1010: RuntimeWarning: divide by zero encountered in double_scalars
#   πA0 = min(m/π2_0_coef,1)
# C:\Users\coolcold1898\Dropbox\COVID-19-Mask\要上傳的程式碼\code files\model_quarantine.py:1001: RuntimeWarning: divide by zero encountered in double_scalars
#   πB = min(m/πB_coef,1)
#        m                   p  q         ICphi       ICn        πB        πA  \
# 0   0.10  0.7013121204816467  0  1.110223e-16 -0.113277  0.158588  0.000000
# 1   0.11  0.7092029863468372  0  0.000000e+00 -0.124603  0.174444  0.000000
# ...

# %%
m_vals=np.linspace(0.1,0.8,71)
σo_set=0.5
σn_set=0.7

result=map(lambda x: SRA1_Qua(x,I_0=0.01,σo=σo_set,σn=σn_set),m_vals)
result=list(result)
data=pd.DataFrame.from_records(result, columns =['func', 'π1','π2','S3','I3','Uphi','Un','Ud'])
data['m']=m_vals
data=data.rename(columns={'func':'D_vals'})


data.to_csv('210407 SRA1 quarantine.csv',index=False)
data
# Out:
# C:\Users\coolcold1898\Dropbox\COVID-19-Mask\要上傳的程式碼\code files\model_quarantine.py:183: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nI_I,nR_I,nR,nD]))
#       D_vals        π1        π2        S3        I3      Uphi        Un  \
# 0   0.001958  0.100098  0.100289  0.894809  0.063388  0.185300  1.335251
# 1   0.001887  0.110107  0.110315  0.898553  0.060473  0.203276  1.348223
# 2   0.001819  0.120117  0.120341  0.902153  0.057685  0.221152  1.361093
# 3   0.001753  0.130127  0.130367  0.905612  0.055017  0.238927  1.373863
# 4   0.001689  0.140137  0.140392  0.908935  0.052467  0.256601  1.386533
# ..       ...       ...       ...       ...       ...       ...       ...
# ...

# %%
m_vals=np.linspace(0.1,0.8,71)
σo_set=0.5
σn_set=0.7

result=map(lambda x: SRA2_Qua(x,I_0=0.01,σo=σo_set,σn=σn_set),m_vals)
result=list(result)
data=pd.DataFrame.from_records(result, columns =['func','π1','π20','π21','S3','I3','Uphi','Un','Ud'])
data['m']=m_vals
data=data.rename(columns={'func':'D_vals'})

data.to_csv('210407 SRA2 quarantine.csv',index=False)
data
# Out:
# C:\Users\coolcold1898\Dropbox\COVID-19-Mask\要上傳的程式碼\code files\model_quarantine.py:183: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nI_I,nR_I,nR,nD]))
#       D_vals        π1       π20       π21        S3        I3      Uphi  \
# 0   0.001945  0.100098  0.111444  0.000000  0.895452  0.062744  0.190319
# 1   0.001872  0.110107  0.123965  0.000000  0.899303  0.059724  0.209350
# 2   0.001801  0.120117  0.136770  0.000000  0.903011  0.056827  0.228379
# 3   0.001733  0.130127  0.149869  0.000000  0.906580  0.054049  0.247409
# 4   0.001667  0.140137  0.163272  0.000000  0.910015  0.051386  0.266438
# ..       ...       ...       ...       ...       ...       ...       ...
# ...
