# %%
from model_TimeExt import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
vo =0.5
vn=0.7
𝜌 = 1
σo=0.5
σn=0.7
𝛿o=0.5
𝛿n=0.7
I=0.01
m_vals=np.linspace(0.1,0.8,71)

param=map(lambda m: GRBT_EXT(m,I_0=I,𝜌=𝜌,σo=σo,σn=σn,δo=δo,δn=δn,vo=vo,vn=vn),m_vals)
paramdata= pd.DataFrame.from_records(list(param), columns =['m','p','q','ICphi','ICn',
                                                            'πB','πA','πA0','πB0','πA1','πB1',
                                                            'πA00','πB00','πA01','πA10','πB01','πB10','πA11','πB11',
                                                            'S4','I4','D_vals','Ud'])
paramdata.to_csv('210407 GRBT TimeExtMaskExp.csv',index=False)
paramdata
# Out:
# C:\Users\coolcold1898\Dropbox\COVID-19-Mask\要上傳的程式碼\code files\model_TimeExt.py:216: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
#        m                   p  q         ICphi       ICn        πB        πA  \
# 0   0.10  0.5555285099018648  0 -7.993606e-15 -0.142873  0.200022  0.000000
# 1   0.11  0.5617708253024285  0  1.076916e-14 -0.157160  0.220024  0.000000
# 2   0.12  0.5681550070908775  0  6.550316e-15 -0.171447  0.240026  0.000000
# 3   0.13  0.5746859472115999  0  9.103829e-15 -0.185734  0.260028  0.000000
# 4   0.14   0.581368765141304  0  2.409184e-14 -0.200021  0.280030  0.000000
# ..   ...                 ... ..           ...       ...       ...       ...
# ...

# %%
result=map(lambda x: SRA1_EXT(x,I_0=0.01,σo=σo,σn=σn,δo=δo,δn=δn),m_vals)
result=list(result)
data=pd.DataFrame.from_records(result, columns =['func', '𝜋1','𝜋2','𝜋3','S4','I4','Ud'])
data['m']=m_vals
data=data.rename(columns={'func':'D_vals'})


data.to_csv('210407 SRA1 TimeExtMaskExp.csv',index=False)
data
# Out:
# C:\Users\coolcold1898\Dropbox\COVID-19-Mask\要上傳的程式碼\code files\model_TimeExt.py:216: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
#       D_vals        𝜋1        𝜋2        𝜋3        S4        I4        Ud     m
# 0   0.001829  0.100006  0.100016  0.100033  0.932612  0.043648  1.149997  0.10
# 1   0.001753  0.110007  0.110018  0.110035  0.934652  0.041974  1.144997  0.11
# 2   0.001680  0.120007  0.120019  0.120038  0.936620  0.040366  1.139996  0.12
# 3   0.001611  0.130008  0.130021  0.130041  0.938517  0.038820  1.134996  0.13
# 4   0.001544  0.140008  0.140022  0.140043  0.940346  0.037335  1.129996  0.14
# ..       ...       ...       ...       ...       ...       ...       ...   ...
# ...

# %%
result=map(lambda x: SRA2_EXT(x,I_0=0.01,σo=σo,σn=σn,δo=δo,δn=δn),m_vals)
result=list(result)
data=pd.DataFrame.from_records(result, columns =['func','𝜋1','𝜋20','𝜋21','𝜋30','𝜋31','𝜋32','S4','I4','Ud'])
data['m']=m_vals
data=data.rename(columns={'func':'D_vals'})


data.to_csv('210407 SRA2 TimeExtMaskExp.csv',index=False)
data
# Out:
# C:\Users\coolcold1898\Dropbox\COVID-19-Mask\要上傳的程式碼\code files\model_TimeExt.py:216: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return(np.array([nS,nI,nR,nD]))
#       D_vals        𝜋1       𝜋20       𝜋21       𝜋30  𝜋31       𝜋32        S4  \
# 0   0.001805  0.100006  0.111130  0.000000  0.125045  0.0  0.000000  0.932961
# 1   0.001724  0.110007  0.123616  0.000000  0.141077  0.0  0.000000  0.935061
# 2   0.001647  0.120007  0.136387  0.000000  0.157952  0.0  0.000000  0.937090
# 3   0.001574  0.130008  0.149450  0.000000  0.175739  0.0  0.000000  0.939049
# 4   0.001503  0.140008  0.162818  0.000000  0.194515  0.0  0.000000  0.940942
# ..       ...       ...       ...       ...       ...  ...       ...       ...
# ...
